# %% [markdown]
# <a href="https://colab.research.google.com/github/tsakailab/iip/blob/main/sandbox/gpu_dataloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNNの実装に挑戦！
#
# 物体認識のCNNモデルを設計し，画像を教師あり学習させます．

# %% [markdown]
# ## 【モデル作り】モデルを定義します．
#
# 下記の例では，torch.nn を用いてモデルを作成しています．
#
# - 入力はチャンネル数3のカラー画像，出力のチャネル数はクラスの数  num_classes で与えられるものとします．
#
# - nn.Sequential()に各層を順に記述することで，特徴抽出部 features，抽出した特徴をベクトルに変換する avgpool，識別部 classifier を定義します．
#     - [畳み込み層](https://pytorch.org/docs/stable/nn.html#convolution-layers)：[nn.Conv2d](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html)
#     - [バッチノルム層](https://pytorch.org/docs/stable/nn.html#normalization-layers)：[nn.BatchNorm2d](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html)
#     - [活性化層](https://pytorch.org/docs/stable/nn.html#non-linear-activations-weighted-sum-nonlinearity)：[nn.ReLU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)，[nn.Sigmoid](https://pytorch.org/docs/stable/generated/torch.nn.Sigmoid.html)
#     - [プーリング層](https://pytorch.org/docs/stable/nn.html#pooling-layers)：[nn.MaxPool2d](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html)，[nn.AvgPool2d](https://pytorch.org/docs/stable/generated/torch.nn.AvgPool2d.html)，[nn.AdaptiveAvgPool2d](https://pytorch.org/docs/stable/generated/torch.nn.AdaptiveAvgPool2d.html)
#     - [全結合層](https://pytorch.org/docs/stable/nn.html#linear-layers)：[nn.Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)
#
# - forward関数で順伝播記述します．
#
# 畳み込み層のチャンネル数（in_channels，out_channels）やカーネルのサイズ（kernel_size）などに調整の余地があるかもしれません．
#
#
# <!--
#         #x = x.mean([-2, -1]) # GAP
#         # x = x.view(x.shape[0], -1) # flatten
# -->

# %%
from torch import nn

class my_model(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1, padding=2, bias=True),
            nn.BatchNorm2d(num_features=32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, 3, padding=1, bias=True),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1, bias=True),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1, bias=True),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))

        self.classifier = nn.Sequential(
            nn.Linear(in_features=256, out_features=num_classes, bias=True)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x).squeeze(-1).squeeze(-1) # [B, C, H=1, W=1] -> [B, C]
        x = self.classifier(x)
        return x

# %% [markdown]
# ###定義どおりにモデルを生成できます．
#
# my_modelで生成すると共に，to(device)でGPUに転送します．

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

nclasses = 2
model = my_model(nclasses).to(device)

from torchsummary import summary
summary(model, (3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]           2,432
#        BatchNorm2d-2         [-1, 32, 128, 128]              64
#               ReLU-3         [-1, 32, 128, 128]               0
#          MaxPool2d-4           [-1, 32, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]          18,496
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               ReLU-7           [-1, 64, 64, 64]               0
#          MaxPool2d-8           [-1, 64, 32, 32]               0
#             Conv2d-9          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-10          [-1, 128, 32, 32]             256
#              ReLU-11          [-1, 128, 32, 32]               0
#         MaxPool2d-12          [-1, 128, 16, 16]               0
#            Conv2d-13          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-14          [-1, 256, 16, 16]             512
#              ReLU-15          [-1, 256, 16, 16]               0
#         MaxPool2d-16            [-1, 256, 8, 8]               0
# AdaptiveAvgPool2d-17            [-1, 256, 1, 1]               0
#            Linear-18                    [-1, 2]             514
# ================================================================
# Total params: 391,426
# Trainable params: 391,426
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 24.38
# Params size (MB): 1.49
# Estimated Total Size (MB): 26.06
# ----------------------------------------------------------------

# %% [markdown]
# ## 【データの入手】教師あり学習に使う画像集合のzipファイルを指定します．
# - zipURL: zipファイルの在処
# - root_dir: zipを展開すると作られるディレクトリ名
# - train_dir, val_dir: 画像集合はroot_dirの中で訓練用と検証用に分けられているものとします．それらのディレクトリ名です．各ディレクトリの下には，クラス名のディレクトリがあり，クラス毎に画像が分けられているものとします．

# %%
zipURL = "https://download.pytorch.org/tutorial/hymenoptera_data.zip"
root_dir, train_dir, val_dir = "./hymenoptera_data", "train", "val"
# zipURL = "https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip"
# root_dir, train_dir, val_dir = "./cats_and_dogs_filtered", "train", "validation"

# %%
#@title 画像集合をダウンロードします．
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import zipfile
import os
# !wget $zipURL --no-check-certificate --show-progress -q -O "./image_dataset.zip"
with zipfile.ZipFile("./image_dataset.zip", 'r') as f:
    f.extractall("./")

class_names = os.listdir(os.path.join(root_dir, train_dir))

from glob import glob
for name in class_names:
    print("train:", name, len(glob(os.path.join(root_dir, train_dir, name, "*"))), 'images')
for name in class_names:
    print("val:", name, len(glob(os.path.join(root_dir, val_dir, name, "*"))), 'images')

from PIL import Image
from torchvision import transforms
preprocess = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
    ])
dic = {}
n = 0
for name in class_names:
    dic[name] = n
    n += 1
train_imgs = []
train_labels = []
for name in class_names:
    for path in glob(os.path.join(root_dir, train_dir, name, "*")):
        img = preprocess(Image.open(path))
        if img.shape[0] != 3:
            img = img.repeat(3, 1, 1)
        train_imgs.append(img)
        train_labels.append(dic[name])

val_imgs = []
val_labels = []
for name in class_names:
    for path in glob(os.path.join(root_dir, val_dir, name, "*")):
        img = preprocess(Image.open(path))
        if img.shape[0] != 3:
            img = img.repeat(3, 1, 1)
        val_imgs.append(img)
        val_labels.append(dic[name])
train_imgs = torch.stack(train_imgs)
val_imgs = torch.stack(val_imgs)

train_labels = torch.tensor(train_labels)
val_labels = torch.tensor(val_labels)
print(train_labels.shape)
print(val_imgs.shape)
print(val_labels.shape)

data_images = {train_dir: train_imgs.to(device), val_dir: val_imgs.to(device)}
labels = {train_dir: train_labels.to(device), val_dir: val_labels.to(device)}
# Out:
# ./image_dataset.zip 100%[===================>]  45.10M  96.8MB/s    in 0.5s
# train: bees 121 images
# train: ants 124 images
# val: bees 83 images
# val: ants 70 images
# torch.Size([245])
# torch.Size([153, 3, 224, 224])
# torch.Size([153])

# %%
hparam = {'batch_size': 16, 'image_size': (224, 224),
          'shuffle': True, 'num_workers': 2,
          'mean_color': [0.485, 0.456, 0.406], 'std_color': [0.229, 0.224, 0.225]}
data_transforms = {
    train_dir:
        transforms.Compose([
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.Normalize(hparam['mean_color'], hparam['std_color'])
    ]),
    val_dir:
        transforms.Compose([
        transforms.Normalize(hparam['mean_color'], hparam['std_color'])
    ]),
}
import time
data = train_imgs.to(device)

start = time.time()
for d in data:
    data_transforms[train_dir](d)
elapsed_time = time.time() - start
print ("cuda elapsed_time:{0}".format(elapsed_time) + "[sec]")

data = train_imgs.cpu()

start = time.time()
for d in data:
    data_transforms[train_dir](d)
elapsed_time = time.time() - start
print ("cpu  elapsed_time:{0}".format(elapsed_time) + "[sec]")

data_images = {train_dir: train_imgs.to(device), val_dir: val_imgs.to(device)}
labels = {train_dir: train_labels.to(device), val_dir: val_labels.to(device)}
# Out:
# cuda elapsed_time:0.07546377182006836[sec]
# cpu  elapsed_time:0.11473488807678223[sec]

# %%
import matplotlib.pyplot as plt
hparam = {'batch_size': 16, 'image_size': (224, 224),
          'shuffle': True, 'num_workers': 2,
          'mean_color': [0.485, 0.456, 0.406], 'std_color': [0.229, 0.224, 0.225]}

# flip =         transforms.Compose([
#         transforms.RandomHorizontalFlip(p=1),
#     ])

# flip =         transforms.Compose([
#         transforms.Normalize(hparam['mean_color'], hparam['std_color'])
#     ])
flip = transforms.Compose(
    [
     transforms.ColorJitter(
         brightness=0, contrast=0, saturation=0.1, hue=(-0.1,0.1)),
     transforms.RandomRotation((-20, 20)),         # transforms.RandomRotation((-180, 180))
     transforms.RandomHorizontalFlip(p=0.5),      # transforms.RandomHorizontalFlip(p=1)
     transforms.RandomVerticalFlip(p=0.5),        # transforms.RandomVerticalFlip(p=1)
     #transforms.RandomPerspective(distortion_scale=0.5, p=1.0)  # distortion_scale=1,p=1.0 
])
fig = plt.figure()
sample = torch.tensor(train_imgs[0]).clone()
plt.imshow(sample.permute(1,2,0))

fig = plt.figure()
plt.imshow(flip(sample.to(device)).cpu().permute(1,2,0))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# ## 【データを読み込む設定】モデルの入出力のため，DataLoaderを作成します．
#
# hparamは，学習に関わる設定値で，予め与える必要がある[ハイパーパラメータ](https://en.wikipedia.org/wiki/Hyperparameter_(machine_learning))です．学習の結果や計算量が変わります．
#
# data_transformsは，train_dirとval_dirにある訓練画像と検証画像の読み込み方を設定するためのdictionary（辞書）です．
# - train_dirに収められた画像をモデルの学習に用います．
# - val_dirにある画像は，訓練画像でない画像に対する識別の性能を観察するために用います．
# - ImageNetの使用に倣って色を正規化します（'mean_color' と 'std_color'）．
# - データ拡張もここで定義します．例：transforms.RandomHorizontalFlip()
# - 訓練画像集合は，batch_size枚の**ミニバッチ（mini batch）**に小分けにして学習させます．

# %%
hparam = {'batch_size': 64, 'image_size': (224, 224),
          'shuffle': True, 'num_workers': 2,
          'mean_color': [0.485, 0.456, 0.406], 'std_color': [0.229, 0.224, 0.225]}

from torchvision import transforms
data_transforms = {
    train_dir:
        transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(
            brightness=0, contrast=0, saturation=0.1, hue=(-0.1,0.1)),
        # transforms.RandomRotation((-20, 20)),         # transforms.RandomRotation((-180, 180))
        # transforms.RandomHorizontalFlip(p=0.5),      # transforms.RandomHorizontalFlip(p=1)
        transforms.RandomVerticalFlip(p=0.5),        # transforms.RandomVerticalFlip(p=1)
        #transforms.RandomPerspective(distortion_scale=0.5, p=1.0)  # distortion_scale=1,p=1.0 
        transforms.Normalize(hparam['mean_color'], hparam['std_color']),
    ]),
    val_dir:
        transforms.Compose([
        transforms.Normalize(hparam['mean_color'], hparam['std_color'])
    ]),
}

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, Dataset
class Mydatasets(torch.utils.data.Dataset):
    def __init__(self, data, labels, transform = None):
        self.transform = transform

        self.data = data
        self.label = labels

        self.datanum = len(data)

    def __len__(self):
        return self.datanum

    def __getitem__(self, idx):
        out_data = self.data[idx]
        out_label = self.label[idx]

        if self.transform:
            out_data = self.transform(out_data)

        return out_data, out_label
    
data_images = {train_dir: train_imgs.to(device), val_dir: val_imgs.to(device)}
labels = {train_dir: train_labels.to(device), val_dir: val_labels.to(device)}
    
image_datasets = {x: Mydatasets(data_images[x], labels[x], data_transforms[x]) for x in [train_dir, val_dir]}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=hparam["batch_size"], shuffle=hparam['shuffle'], num_workers=0) for x in [train_dir, val_dir]}

start = time.time()
for d, l in dataloaders[train_dir]:
    pass
elapsed_time = time.time() - start
print ("cuda data loader elapsed_time:{0}".format(elapsed_time) + "[sec]")

data_images = {train_dir: train_imgs, val_dir: val_imgs}
labels = {train_dir: train_labels, val_dir: val_labels}

image_datasets = {x: Mydatasets(data_images[x], labels[x], data_transforms[x]) for x in [train_dir, val_dir]}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=hparam["batch_size"], shuffle=hparam['shuffle'], num_workers=hparam['num_workers']) for x in [train_dir, val_dir]}

start = time.time()
for d, l in dataloaders[train_dir]:
    pass
elapsed_time = time.time() - start
print ("cpu  data loader elapsed_time:{0}".format(elapsed_time) + "[sec]")


data_images = {train_dir: train_imgs, val_dir: val_imgs}
labels = {train_dir: train_labels, val_dir: val_labels}

image_datasets = {x: Mydatasets(data_images[x], labels[x], data_transforms[x]) for x in [train_dir, val_dir]}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=hparam["batch_size"], shuffle=hparam['shuffle'], num_workers=hparam['num_workers'], pin_memory=True) for x in [train_dir, val_dir]}

start = time.time()
for d, l in dataloaders[train_dir]:
    pass
elapsed_time = time.time() - start
print ("cpu  data loader (pin_memory=True) elapsed_time:{0}".format(elapsed_time) + "[sec]")
# Out:
# cuda data loader elapsed_time:0.8998708724975586[sec]
# cpu  data loader elapsed_time:2.6366498470306396[sec]
# cpu  data loader (pin_memory=True) elapsed_time:2.6071836948394775[sec]

# %%
#@title DataLoader を作成し，訓練画像のミニバッチの例を表示します．
import torch
# from torchvision import datasets
import os
# image_datasets = {x: datasets.ImageFolder(os.path.join(root_dir, x), data_transforms[x])
#                   for x in [train_dir, val_dir]}
# dataset_sizes = {x: len(image_datasets[x]) for x in [train_dir, val_dir]}
# class_names = image_datasets[train_dir].classes
# print("dataset sizes:", dataset_sizes, ", class_names:", class_names)

# dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=hparam['batch_size'],
#                                               shuffle=hparam['shuffle'], num_workers=hparam['num_workers'])
#                for x in [train_dir, val_dir]}
# data_transforms = {
#     train_dir:
#         transforms.Compose([
#         transforms.RandomHorizontalFlip(),
#         transforms.Normalize(hparam['mean_color'], hparam['std_color'])
#     ]),
#     val_dir:
#         transforms.Compose([
#         transforms.Normalize(hparam['mean_color'], hparam['std_color'])
#     ]),
# }
import torch
from torch.utils.data import TensorDataset, DataLoader, Dataset
class Mydatasets(torch.utils.data.Dataset):
    def __init__(self, data, labels, transform = None):
        self.transform = transform

        self.data = data
        self.label = labels

        self.datanum = len(data)
        self.classes = class_names

    def __len__(self):
        return self.datanum

    def __getitem__(self, idx):
        out_data = self.data[idx]
        out_label = self.label[idx]

        if self.transform:
            out_data = self.transform(out_data)

        return out_data, out_label
    
data_images = {train_dir: train_imgs.to(device), val_dir: val_imgs.to(device)}
labels = {train_dir: train_labels.to(device), val_dir: val_labels.to(device)}
    
image_datasets = {x: Mydatasets(data_images[x], labels[x], data_transforms[x]) for x in [train_dir, val_dir]}
dataloaders = {x: DataLoader(image_datasets[x], batch_size=hparam["batch_size"], shuffle=hparam['shuffle'], num_workers=0) for x in [train_dir, val_dir]}

dataset_sizes = {x: len(image_datasets[x]) for x in [train_dir, val_dir]}
class_names = image_datasets[train_dir].classes
print("dataset sizes:", dataset_sizes, ", class_names:", class_names)

start = time.time()
for d, l in dataloaders[train_dir]:
    pass
elapsed_time = time.time() - start
print ("cuda data loader elapsed_time:{0}".format(elapsed_time) + "[sec]")

import numpy as np
import matplotlib.pyplot as plt
def plotImages(img_arr, lbl_arr, colors_arr=None, figsize=(8, 4),
               mean=np.array(hparam['mean_color']), std = np.array(hparam['std_color'])):

    if len(img_arr) <= min(figsize): rc = (1, len(img_arr))
    else: rc = (figsize[1], min(len(img_arr)//figsize[1], figsize[0]))
    fig, axes = plt.subplots(rc[0], rc[1], figsize=(rc[1]*2, rc[0]*2))
    axes = axes.flatten()
    if colors_arr is None: colors_arr = ['k']*len(lbl_arr)
    for img, lbl, c, ax in zip( img_arr, lbl_arr, colors_arr, axes):
        img = img.cpu().numpy().transpose((1,2,0))
        img = std * img + mean
        img = np.clip(img, 0, 1)
        ax.imshow(img)
        ax.set_title(lbl, color=c)
        ax.axis('off')
    plt.tight_layout()
    plt.show()

inputs, labels = next(iter(dataloaders[train_dir]))
print("Input batch of shape [B, C, H, W] =", inputs.shape)
plotImages(inputs, [class_names[l] for l in labels])
# Out:
# dataset sizes: {'train': 245, 'val': 153} , class_names: ['bees', 'ants']
# cuda data loader elapsed_time:0.8071155548095703[sec]
# Input batch of shape [B, C, H, W] = torch.Size([64, 3, 224, 224])

# %% [markdown]
# ## モデルを生成します

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

nclasses = len(class_names)
model = my_model(nclasses).to(device)

from torchsummary import summary
summary(model, (3, hparam['image_size'][0], hparam['image_size'][1]))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]           2,432
#        BatchNorm2d-2         [-1, 32, 224, 224]              64
#               ReLU-3         [-1, 32, 224, 224]               0
#          MaxPool2d-4         [-1, 32, 112, 112]               0
#             Conv2d-5         [-1, 64, 112, 112]          18,496
#        BatchNorm2d-6         [-1, 64, 112, 112]             128
#               ReLU-7         [-1, 64, 112, 112]               0
#          MaxPool2d-8           [-1, 64, 56, 56]               0
#             Conv2d-9          [-1, 128, 56, 56]          73,856
#       BatchNorm2d-10          [-1, 128, 56, 56]             256
#              ReLU-11          [-1, 128, 56, 56]               0
#         MaxPool2d-12          [-1, 128, 28, 28]               0
#            Conv2d-13          [-1, 256, 28, 28]         295,168
#       BatchNorm2d-14          [-1, 256, 28, 28]             512
#              ReLU-15          [-1, 256, 28, 28]               0
#         MaxPool2d-16          [-1, 256, 14, 14]               0
# AdaptiveAvgPool2d-17            [-1, 256, 1, 1]               0
#            Linear-18                    [-1, 2]             514
# ================================================================
# Total params: 391,426
# Trainable params: 391,426
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 74.65
# Params size (MB): 1.49
# Estimated Total Size (MB): 76.72
# ----------------------------------------------------------------

# %% [markdown]
# ## 【学習の設定】[損失関数](https://pytorch.org/docs/stable/nn.html#loss-functions)と[最適化のアルゴリズム](https://pytorch.org/docs/stable/optim.html)を指定します．
#
# モデルの学習とは，入力画像から正しく識別結果を出力できるようにモデルの学習可能パラメータ（Trainable parameters）を調整することです．出力の正しさは損失関数（loss function）で評価します．損失ができるだけ小さな値になるように学習可能パラメータを調整する計算の方法が最適化のアルゴリズムです．
#
# 最適化のアルゴリズムでは，学習可能パラメータを少しずつ修正して，損失関数を徐々に小さくします．この修正を反復した結果，訓練画像すべてに対して損失関数が十分に小さくなるような学習可能パラメータ（畳み込み層のカーネルや全結合層の重み）が求まります．
#
# 訓練画像集合のミニバッチ毎に学習可能パラメータは修正されます．最適化において，すべての訓練画像が一巡する回数をエポック（epoch）といいます．収束に必要なエポック数は数～数百で，最適化問題とアルゴリズムに依存します．
#
# - 識別の評価には交差エントロピー損失関数[nn.CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)を使います．モデルが識別結果を正しく出力できるほど，損失は小さいと評価します．
# - 定番の最適化のアルゴリズムは[Adam](https://arxiv.org/abs/1412.6980)です．[optim.Adam](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html)のオプション lr で学習率を設定します．
# - 学習率とは，学習可能パラメータを修正する大きさの目安です．小さすぎると収束までに時間がかかります．大きすぎると損失関数が徐々に小さくならずに発散します．ハイパーパラメータ hparam['learning_rate']で指定します．
# - エポック数もハイパーパラメータです．hparam['epochs']で指定します．

# %%
criterion = nn.CrossEntropyLoss()

from torch import optim
hparam['learning_rate'] = 0.0001
optimizer_ft = optim.Adam(model.parameters(), lr=hparam['learning_rate'])

#hparam['momentum'] = 0.9
#optimizer_ft = optim.SGD(model.parameters(), lr=hparam['learning_rate'], momentum=hparam['momentum'])

hparam['epochs'] = 20

# %%
#@title 学習を実行する関数 run_training を定義します．
import time
import copy
 ## Define some function(training, printing result)
def run_training(model, criterion, optimizer, num_epochs=20):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    loss_dict = {train_dir: [], val_dir: []}
    acc_dict = {train_dir: [], val_dir: []}
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in [train_dir, val_dir]:
            if phase == train_dir:
                model.train()  # Set model to training mode
            
                running_loss = 0.0
                running_corrects = 0
                for inputs, labels in dataloaders[phase]:

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == train_dir):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        loss.backward()
                        optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]
                loss_dict[phase].append(epoch_loss)
                acc_dict[phase].append(epoch_acc)

                print('{} loss: {:.4f},  acc: {:.4f}'.format(
                    phase, epoch_loss, epoch_acc))

            else:
                model.eval()   # Set model to evaluate mode
                with torch.no_grad():
            
                    running_loss = 0.0
                    running_corrects = 0

                    # Iterate over data.
                    for inputs, labels in dataloaders[phase]:

                        # zero the parameter gradients
                        optimizer.zero_grad()

                        # forward
                        # track history if only in train
                        with torch.set_grad_enabled(phase == train_dir):
                            outputs = model(inputs)
                            _, preds = torch.max(outputs, 1)
                            loss = criterion(outputs, labels)

                        # statistics
                        running_loss += loss.item() * inputs.size(0)
                        running_corrects += torch.sum(preds == labels.data)

                    epoch_loss = running_loss / dataset_sizes[phase]
                    epoch_acc = running_corrects.double() / dataset_sizes[phase]
                    loss_dict[phase].append(epoch_loss)
                    acc_dict[phase].append(epoch_acc)

                    print('{} loss: {:.4f},  acc: {:.4f}'.format(
                        phase, epoch_loss, epoch_acc))

                    # deep copy the model
                    if epoch_acc > best_acc:
                        best_acc = epoch_acc
                        best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, loss_dict, acc_dict

# %% [markdown]
# ## 【学習の実行】モデルを最適化します．
#
# 注意：とても時間がかかることがあります．この例では数分～数十分が目安です．停止ボタンで停止したときは，モデルの生成（※）のセルから実行し直してください．
#
# - train loss が徐々に減少し，acc（0<=acc<=1）が上昇傾向ですか．

# %%
model_ft, loss_dict, acc_dict = run_training(model, criterion, optimizer_ft, num_epochs=64)
# Out:
# Epoch 0/63
# ----------
# train loss: 0.7242,  acc: 0.5306
# val loss: 0.6844,  acc: 0.5425
#
# Epoch 1/63
# ----------
# train loss: 0.6231,  acc: 0.6286
# val loss: 0.6822,  acc: 0.5425
#
# Epoch 2/63
# ----------
# train loss: 0.6056,  acc: 0.6204
# val loss: 0.6738,  acc: 0.5425
#
# Epoch 3/63
# ----------
# train loss: 0.5845,  acc: 0.6857
# val loss: 0.6628,  acc: 0.6144
#
# Epoch 4/63
# ----------
# train loss: 0.5758,  acc: 0.7143
# val loss: 0.6510,  acc: 0.6667
#
# Epoch 5/63
# ----------
# train loss: 0.5679,  acc: 0.7102
# val loss: 0.6319,  acc: 0.6863
#
# Epoch 6/63
# ----------
# train loss: 0.5506,  acc: 0.7102
# val loss: 0.6138,  acc: 0.6863
#
# Epoch 7/63
# ----------
# train loss: 0.5452,  acc: 0.7061
# val loss: 0.6062,  acc: 0.6536
#
# Epoch 8/63
# ----------
# train loss: 0.5338,  acc: 0.7469
# val loss: 0.6044,  acc: 0.6471
#
# Epoch 9/63
# ----------
# train loss: 0.5156,  acc: 0.7429
# val loss: 0.5772,  acc: 0.6667
#
# Epoch 10/63
# ----------
# train loss: 0.5254,  acc: 0.7388
# val loss: 0.5815,  acc: 0.6928
#
# Epoch 11/63
# ----------
# train loss: 0.5279,  acc: 0.7347
# val loss: 0.5610,  acc: 0.7190
#
# Epoch 12/63
# ----------
# train loss: 0.5045,  acc: 0.7388
# val loss: 0.5810,  acc: 0.7255
#
# Epoch 13/63
# ----------
# train loss: 0.5050,  acc: 0.7184
# val loss: 0.5551,  acc: 0.7386
#
# Epoch 14/63
# ----------
# train loss: 0.4943,  acc: 0.7469
# val loss: 0.5836,  acc: 0.6928
#
# Epoch 15/63
# ----------
# train loss: 0.4998,  acc: 0.7673
# val loss: 0.5523,  acc: 0.7320
#
# Epoch 16/63
# ----------
# train loss: 0.4907,  acc: 0.7469
# val loss: 0.5389,  acc: 0.7320
#
# Epoch 17/63
# ----------
# train loss: 0.4827,  acc: 0.7633
# val loss: 0.5593,  acc: 0.7059
#
# Epoch 18/63
# ----------
# train loss: 0.4870,  acc: 0.7714
# val loss: 0.5425,  acc: 0.7451
#
# Epoch 19/63
# ----------
# train loss: 0.4798,  acc: 0.7959
# val loss: 0.5226,  acc: 0.7582
#
# Epoch 20/63
# ----------
# train loss: 0.4623,  acc: 0.7959
# val loss: 0.5034,  acc: 0.7386
#
# Epoch 21/63
# ----------
# train loss: 0.4519,  acc: 0.7714
# val loss: 0.5145,  acc: 0.7843
#
# Epoch 22/63
# ----------
# train loss: 0.4920,  acc: 0.7347
# val loss: 0.5235,  acc: 0.7582
#
# Epoch 23/63
# ----------
# train loss: 0.4759,  acc: 0.7469
# val loss: 0.5173,  acc: 0.7451
#
# Epoch 24/63
# ----------
# train loss: 0.4740,  acc: 0.7633
# val loss: 0.5099,  acc: 0.7516
#
# Epoch 25/63
# ----------
# train loss: 0.4615,  acc: 0.7673
# val loss: 0.5310,  acc: 0.7582
#
# Epoch 26/63
# ----------
# train loss: 0.4643,  acc: 0.7673
# val loss: 0.6068,  acc: 0.7190
#
# Epoch 27/63
# ----------
# train loss: 0.4378,  acc: 0.7755
# val loss: 0.5515,  acc: 0.7516
#
# Epoch 28/63
# ----------
# train loss: 0.4459,  acc: 0.7837
# val loss: 0.5351,  acc: 0.7190
#
# Epoch 29/63
# ----------
# train loss: 0.4561,  acc: 0.7633
# val loss: 0.5413,  acc: 0.7582
#
# Epoch 30/63
# ----------
# train loss: 0.4425,  acc: 0.7796
# val loss: 0.5948,  acc: 0.7320
#
# Epoch 31/63
# ----------
# train loss: 0.4700,  acc: 0.7633
# val loss: 0.5956,  acc: 0.7320
#
# Epoch 32/63
# ----------
# train loss: 0.4533,  acc: 0.7796
# val loss: 0.5335,  acc: 0.7451
#
# Epoch 33/63
# ----------
# train loss: 0.4590,  acc: 0.7388
# val loss: 0.5043,  acc: 0.7320
#
# Epoch 34/63
# ----------
# train loss: 0.4405,  acc: 0.7755
# val loss: 0.6161,  acc: 0.7386
#
# Epoch 35/63
# ----------
# train loss: 0.4301,  acc: 0.8000
# val loss: 0.5458,  acc: 0.7778
#
# Epoch 36/63
# ----------
# train loss: 0.4439,  acc: 0.7755
# val loss: 0.5416,  acc: 0.7582
#
# Epoch 37/63
# ----------
# train loss: 0.4505,  acc: 0.7673
# val loss: 0.5289,  acc: 0.7386
#
# Epoch 38/63
# ----------
# train loss: 0.4346,  acc: 0.7796
# val loss: 0.5280,  acc: 0.7190
#
# Epoch 39/63
# ----------
# train loss: 0.4142,  acc: 0.8082
# val loss: 0.5477,  acc: 0.7190
#
# Epoch 40/63
# ----------
# train loss: 0.4260,  acc: 0.8000
# val loss: 0.6109,  acc: 0.7255
#
# Epoch 41/63
# ----------
# train loss: 0.4158,  acc: 0.8041
# val loss: 0.5576,  acc: 0.7647
#
# Epoch 42/63
# ----------
# train loss: 0.4030,  acc: 0.7878
# val loss: 0.5467,  acc: 0.7451
#
# Epoch 43/63
# ----------
# train loss: 0.4029,  acc: 0.8041
# val loss: 0.5568,  acc: 0.7647
#
# Epoch 44/63
# ----------
# train loss: 0.4017,  acc: 0.8204
# val loss: 0.5535,  acc: 0.7582
#
# Epoch 45/63
# ----------
# train loss: 0.3915,  acc: 0.8327
# val loss: 0.5311,  acc: 0.7843
#
# Epoch 46/63
# ----------
# train loss: 0.4116,  acc: 0.7959
# val loss: 0.5767,  acc: 0.7516
#
# Epoch 47/63
# ----------
# train loss: 0.4081,  acc: 0.8082
# val loss: 0.5783,  acc: 0.7712
#
# Epoch 48/63
# ----------
# train loss: 0.4335,  acc: 0.7918
# val loss: 0.6026,  acc: 0.7451
#
# Epoch 49/63
# ----------
# train loss: 0.4194,  acc: 0.7878
# val loss: 0.5677,  acc: 0.7451
#
# Epoch 50/63
# ----------
# train loss: 0.4004,  acc: 0.8122
# val loss: 0.6052,  acc: 0.7320
#
# Epoch 51/63
# ----------
# train loss: 0.4067,  acc: 0.8163
# val loss: 0.5434,  acc: 0.7386
#
# Epoch 52/63
# ----------
# train loss: 0.3988,  acc: 0.7959
# val loss: 0.5799,  acc: 0.7516
#
# Epoch 53/63
# ----------
# train loss: 0.3940,  acc: 0.7918
# val loss: 0.5635,  acc: 0.7647
#
# Epoch 54/63
# ----------
# train loss: 0.4400,  acc: 0.8000
# val loss: 0.5611,  acc: 0.7974
#
# Epoch 55/63
# ----------
# train loss: 0.4030,  acc: 0.8204
# val loss: 0.5986,  acc: 0.7320
#
# Epoch 56/63
# ----------
# train loss: 0.3883,  acc: 0.8204
# val loss: 0.5559,  acc: 0.7582
#
# Epoch 57/63
# ----------
# train loss: 0.3939,  acc: 0.8163
# val loss: 0.5671,  acc: 0.7778
#
# Epoch 58/63
# ----------
# train loss: 0.3951,  acc: 0.8204
# val loss: 0.5847,  acc: 0.7451
#
# Epoch 59/63
# ----------
# train loss: 0.3847,  acc: 0.8000
# val loss: 0.6132,  acc: 0.7320
#
# Epoch 60/63
# ----------
# train loss: 0.3621,  acc: 0.8408
# val loss: 0.5841,  acc: 0.7778
#
# Epoch 61/63
# ----------
# train loss: 0.3540,  acc: 0.8204
# val loss: 0.5861,  acc: 0.7190
#
# Epoch 62/63
# ----------
# train loss: 0.3973,  acc: 0.8082
# val loss: 0.5431,  acc: 0.7451
#
# Epoch 63/63
# ----------
# train loss: 0.3947,  acc: 0.8122
# val loss: 0.6453,  acc: 0.7386
#
# Training complete in 2m 25s
# Best val Acc: 0.797386

# %%
#@title 学習の過程における損失関数と正答率の変化を表示します．
def plotting_history(loss_dict, acc_dict):
    epoch = len(loss_dict[train_dir])
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 8))
    axes[0].plot(range(epoch), loss_dict[train_dir], label=train_dir)
    axes[0].plot(range(epoch), loss_dict[val_dir], label=val_dir)
    axes[0].set_title("Loss")
    axes[0].legend()

    axes[1].plot(range(epoch), acc_dict[train_dir], label=train_dir)
    axes[1].plot(range(epoch), acc_dict[val_dir], label=val_dir)
    axes[1].set_title("Accuracy")
    axes[1].legend()

plotting_history(loss_dict, acc_dict)

# %%
#@title 検証用の画像に対する結果を例示します（このセルを実行する度に例が変わります）．
inputs, labels = next(iter(dataloaders[val_dir]))
model.eval()
with torch.no_grad():
    outputs = model(inputs.to(device))

probabilities = nn.functional.softmax(outputs, dim=1)
_, preds = torch.max(probabilities, dim=1)

lbl_preds = [class_names[l] for l in preds]
lbl_gts = [class_names[l] for l in labels]
colors_arr = ['blue' if g== p else 'red' for g, p in zip(lbl_gts, lbl_preds)]

print("(ground truth, prediction)")
plotImages(inputs.cpu(), ["(" + g + ", " + p + ")" for g, p in zip(lbl_gts, lbl_preds)], colors_arr=colors_arr)
# Out:
# (ground truth, prediction)

# %% [markdown]
# # モデルの保存

# %%
torch.save(model_ft, "sample_model.pkl")
# torch.save(model_ft, "sample_model") # こっちでも
# !ls
sample_model = torch.load("sample_model.pkl")
print(sample_model)

print(sample_model.features[0].weight[0, 0])
print(model_ft.features[0].weight[0, 0])
# Out:
# cats_and_dogs_filtered	image_dataset.zip  sample_model.pkl  smaple_model.pkl
# hymenoptera_data	sample_data	   smaple_model
# my_model(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU()
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=2, bias=True)
#   )
# )
# tensor([[ 0.0985, -0.0020,  0.1075, -0.0494, -0.1002],
#         [ 0.1004, -0.0123,  0.0199, -0.0007, -0.0201],
#         [ 0.0744,  0.0853,  0.0401, -0.0671, -0.0786],
#         [-0.0822, -0.0240, -0.0583,  0.0332, -0.0821],
#         [-0.0976, -0.0470, -0.0115, -0.1097,  0.0893]], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# tensor([[ 0.0985, -0.0020,  0.1075, -0.0494, -0.1002],
#         [ 0.1004, -0.0123,  0.0199, -0.0007, -0.0201],
#         [ 0.0744,  0.0853,  0.0401, -0.0671, -0.0786],
#         [-0.0822, -0.0240, -0.0583,  0.0332, -0.0821],
#         [-0.0976, -0.0470, -0.0115, -0.1097,  0.0893]], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
# set random input image
import random
from PIL import Image
target_num = 1
target = ['ants','bees'][target_num]
img = Image.open('./hymenoptera_data/val/{}/'.format(target) + random.choice(os.listdir('./hymenoptera_data/val/{}/'.format(target))))
preprocess = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(hparam['mean_color'], hparam['std_color']),
    ])
img = preprocess(img)
# prepare the input image for plot
inp = img
inp = inp.numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
inp = std * inp + mean
inp = np.clip(inp, 0, 1)

# extract layers
model_features = model_ft.features
model_dense = model_ft.classifier[0]

# make layer used to make cam
cam_extractor = torch.nn.Conv2d(model_dense.weight.shape[1], model_dense.weight.shape[0], 1, padding=0, bias=False)
cam_extractor.weight = torch.nn.Parameter(model_dense.weight.unsqueeze(-1).unsqueeze(-1))

# calc feature maps
features = model_features(img.unsqueeze(0).to(device))

# predict
pooled = features.mean([-2,-1])
pred = model_dense(pooled)

# calc cam
cam = cam_extractor(features)
cam = cam.squeeze()

# normalize cam
cam_min = torch.min(cam)
cam_max = torch.max(cam - cam_min)
cam = (cam - cam_min)/cam_max

# resize cam
resizing_function = transforms.Compose([
        transforms.Resize(224),
    ])
cam = resizing_function(cam)

def toHeatmap(x):
    x = (x*255).reshape(-1)
    cm = plt.get_cmap('jet')
    x = np.array([cm(int(np.round(xi)))[:3] for xi in x]) # ここの処理が重い．
    width = img.shape[-1]
    return x.reshape(width,width,3)

# make cam heatmap
cam = [toHeatmap(cam[0].detach().cpu()),
       toHeatmap(cam[1].detach().cpu())]

# set alpha value
alpha = 0.5

# mask input image by cam
cam_image = inp*alpha + cam[target_num]*(1-alpha)

# plot
fig = plt.figure(figsize = (15,8))
plt.subplot(1,4,1)
plt.imshow(inp)
plt.title('input:{}'.format(['ants','bees'][target_num]))
plt.subplot(1,4,2)
plt.title('input with cam\npredicted as {}'.format(['ants','bees'][torch.max(pred, 1)[1].item()]))
plt.imshow(cam_image)
plt.subplot(1,4,3)
plt.imshow(cam[0])
plt.title('cam:{}'.format(['ants','bees'][0]))
plt.subplot(1,4,4)
plt.imshow(cam[1])
plt.title('cam:{}'.format(['ants','bees'][1]))
# Out:
# Text(0.5, 1.0, 'cam:bees')
